# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/HESS_Dataset.csv')

# %%
df.head()
# Out:
#              Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 0  2024-04-01 00:00:00       18.727006       7.405317       8.925585
# 1  2024-04-01 01:00:00       47.535715      21.676038       8.704682
# 2  2024-04-01 02:00:00       36.599697      34.917833      18.593819
# 3  2024-04-01 03:00:00       29.932924      29.288995       8.743193
# 4  2024-04-01 04:00:00        7.800932      32.262446       9.079246
#
#    Battery_SoC_%  SC_Charge_kW  Hydrogen_Production_kg/h  Load_Demand_kW  \
# 0      73.816240      5.719959                  1.968178       62.412848
# 1      83.734512      8.054323                  2.367178       38.619318
# 2      40.037432      7.601609                  4.272737       73.619728
# 3      69.989928      1.538999                  1.700022       60.655812
# 4      65.739679      1.492495                  4.348248       37.860194
#
#    Power_Supplied_kW  Power_Loss_kW   Optimization_Level
# 0          62.218850       0.193997      High Efficiency
# 1          37.685455       0.933863      High Efficiency
# 2          69.463499       4.156229  Moderate Efficiency
# 3          56.821970       3.833842  Moderate Efficiency
# 4          36.106981       1.753213      High Efficiency

# %%
df.isnull().sum()
# Out:
# Timestamp                   0
# Solar_Power_kW              0
# Wind_Power_kW               0
# Grid_Power_kW               0
# Battery_SoC_%               0
# SC_Charge_kW                0
# Hydrogen_Production_kg/h    0
# Load_Demand_kW              0
# Power_Supplied_kW           0
# Power_Loss_kW               0
# Optimization_Level          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Timestamp                 1000 non-null   object
#  1   Solar_Power_kW            1000 non-null   float64
#  2   Wind_Power_kW             1000 non-null   float64
#  3   Grid_Power_kW             1000 non-null   float64
#  4   Battery_SoC_%             1000 non-null   float64
#  5   SC_Charge_kW              1000 non-null   float64
#  6   Hydrogen_Production_kg/h  1000 non-null   float64
#  7   Load_Demand_kW            1000 non-null   float64
#  8   Power_Supplied_kW         1000 non-null   float64
#  9   Power_Loss_kW             1000 non-null   float64
#  10  Optimization_Level        1000 non-null   object
# dtypes: float64(9), object(2)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#        Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  Battery_SoC_%  \
# count     1000.000000    1000.000000    1000.000000    1000.000000
# mean        24.512828      20.280692      12.536086      59.230004
# std         14.606868      11.687596       4.360113      22.919148
# min          0.231601       0.128731       5.000175      20.052271
# 25%         11.798663       9.642971       8.920265      39.352062
# 50%         24.840369      20.749356      12.509209      58.742343
# 75%         37.215979      30.418602      16.386553      79.003265
# max         49.985884      39.976549      19.967313      99.964616
#
#        SC_Charge_kW  Hydrogen_Production_kg/h  Load_Demand_kW  \
# count   1000.000000               1000.000000     1000.000000
# mean       4.941053                  2.492322       54.665442
# std        2.868099                  1.445974       14.486682
# min        0.000307                  0.030919       30.071417
# 25%        2.449740                  1.246900       42.011083
# 50%        4.945981                  2.452014       54.232151
# 75%        7.399935                  3.699259       67.823217
# max        9.977494                  4.996752       79.973034
#
#        Power_Supplied_kW  Power_Loss_kW
# count        1000.000000    1000.000000
# mean           52.253589       2.411853
# std            14.502363       1.424572
# min            26.384289       0.001205
# 25%            39.522335       1.179946
# 50%            52.183199       2.419953
# 75%            65.169327       3.572331
# max            79.127117       4.994523
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17['Solar_Power_kW'].plot(kind='hist', bins=20, title='Solar_Power_kW')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['Wind_Power_kW'].plot(kind='hist', bins=20, title='Wind_Power_kW')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Grid_Power_kW'].plot(kind='hist', bins=20, title='Grid_Power_kW')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['Battery_SoC_%'].plot(kind='hist', bins=20, title='Battery_SoC_%')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='Solar_Power_kW', y='Wind_Power_kW', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='Wind_Power_kW', y='Grid_Power_kW', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23.plot(kind='scatter', x='Grid_Power_kW', y='Battery_SoC_%', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24.plot(kind='scatter', x='Battery_SoC_%', y='SC_Charge_kW', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25['Solar_Power_kW'].plot(kind='line', figsize=(8, 4), title='Solar_Power_kW')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['Wind_Power_kW'].plot(kind='line', figsize=(8, 4), title='Wind_Power_kW')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['Grid_Power_kW'].plot(kind='line', figsize=(8, 4), title='Grid_Power_kW')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['Battery_SoC_%'].plot(kind='line', figsize=(8, 4), title='Battery_SoC_%')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x = df.drop('Optimization_Level', axis=1)
y = df['Optimization_Level']

# %%
x
# Out:
#                Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 0    2024-04-01 00:00:00       18.727006       7.405317       8.925585
# 1    2024-04-01 01:00:00       47.535715      21.676038       8.704682
# 2    2024-04-01 02:00:00       36.599697      34.917833      18.593819
# 3    2024-04-01 03:00:00       29.932924      29.288995       8.743193
# 4    2024-04-01 04:00:00        7.800932      32.262446       9.079246
# ..                   ...             ...            ...            ...
# 995  2024-05-12 11:00:00        4.579104      26.278206      17.979436
# 996  2024-05-12 12:00:00       45.865679      38.264585       7.359098
# 997  2024-05-12 13:00:00        6.840932       2.758321       9.646818
# 998  2024-05-12 14:00:00       47.511868       2.282189       9.350683
# 999  2024-05-12 15:00:00       22.300289      11.287483      18.071211
#
#      Battery_SoC_%  SC_Charge_kW  Hydrogen_Production_kg/h  Load_Demand_kW  \
# 0        73.816240      5.719959                  1.968178       62.412848
# 1        83.734512      8.054323                  2.367178       38.619318
# 2        40.037432      7.601609                  4.272737       73.619728
# 3        69.989928      1.538999                  1.700022       60.655812
# 4        65.739679      1.492495                  4.348248       37.860194
# ..             ...           ...                       ...             ...
# 995      55.368563      8.973973                  3.422177       58.986856
# 996      46.752094      1.193810                  2.516102       63.351843
# 997      51.565785      3.278428                  3.825744       75.578844
# 998      62.395247      8.157454                  2.426453       47.281008
# 999      32.909389      5.973124                  0.746908       61.075366
#
#      Power_Supplied_kW  Power_Loss_kW
# 0            62.218850       0.193997
# 1            37.685455       0.933863
# 2            69.463499       4.156229
# 3            56.821970       3.833842
# 4            36.106981       1.753213
# ..                 ...            ...
# 995          57.621058       1.365798
# 996          62.304247       1.047596
# 997          73.302201       2.276644
# 998          42.738821       4.542188
# 999          60.552964       0.522402
#
# [1000 rows x 10 columns]

# %%
y
# Out:
# 0          High Efficiency
# 1          High Efficiency
# 2      Moderate Efficiency
# 3      Moderate Efficiency
# 4          High Efficiency
#               ...
# 995        High Efficiency
# 996        High Efficiency
# 997        High Efficiency
# 998    Moderate Efficiency
# 999        High Efficiency
# Name: Optimization_Level, Length: 1000, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#                Timestamp  Solar_Power_kW  Wind_Power_kW  Grid_Power_kW  \
# 29   2024-04-02 05:00:00        2.322521      33.156619      14.812619
# 535  2024-04-23 07:00:00       47.238286       4.875444      17.512169
# 695  2024-04-29 23:00:00       30.531002       2.726892      12.785484
# 557  2024-04-24 05:00:00        1.439134      16.441139       9.493485
# 836  2024-05-05 20:00:00       45.742295       5.123830      19.898825
# ..                   ...             ...            ...            ...
# 106  2024-04-05 10:00:00       20.519146      15.849681      17.857689
# 270  2024-04-12 06:00:00       40.468058      27.799275       6.563372
# 860  2024-05-06 20:00:00       38.776381      31.057898      18.001555
# 435  2024-04-19 03:00:00       35.048457       1.198944      10.842228
# 102  2024-04-05 06:00:00       15.717799      35.351435       7.369322
#
#      Battery_SoC_%  SC_Charge_kW  Hydrogen_Production_kg/h  Load_Demand_kW  \
# 29       70.582572      3.604745                  0.606515       35.058281
# 535      30.374318      5.879916                  0.521565       42.517936
# 695      22.408310      8.799146                  1.547313       67.044160
# 557      59.026745      6.790666                  3.679602       32.646797
# 836      94.604390      3.773632                  4.432977       48.331885
# ..             ...           ...                       ...             ...
# 106      77.875825      9.653027                  1.833992       54.651506
# 270      40.261791      6.487654                  0.963382       47.500343
# 860      85.173680      6.254335                  2.276975       33.595336
# 435      51.138438      2.806008                  3.697906       58.107238
# 102      93.163893      5.481452                  2.854535       45.961265
#
#      Power_Supplied_kW  Power_Loss_kW
# 29           34.297140       0.761141
# 535          39.011470       3.506467
# 695          63.653548       3.390613
# 557          30.107310       2.539487
# 836          45.303389       3.028496
# ..                 ...            ...
# 106          54.510550       0.140957
# 270          45.896783       1.603561
# 860          33.318674       0.276662
# 435          53.623505       4.483733
# 102          41.166144       4.795121
#
# [800 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
